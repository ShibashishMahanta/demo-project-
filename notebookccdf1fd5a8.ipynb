# %%
from skimage import io, feature
import matplotlib.pyplot as plt

# Load the image
image = io.imread('pic1.jpg', as_gray=True)

# Apply Local Binary Pattern (LBP)
lbp = feature.local_binary_pattern(image, P=8, R=1, method='uniform')

# Display the original image and the LBP result
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')
plt.subplot(1, 2, 2)
plt.title('LBP')
plt.imshow(lbp, cmap='gray')
plt.show()
# Out:
# C:\Users\rajma\anaconda3\Lib\site-packages\skimage\feature\texture.py:360: UserWarning: Applying `local_binary_pattern` to floating-point images may give unexpected results when small numerical differences between adjacent pixels are present. It is recommended to use this function with images of integer dtype.
#
#   warnings.warn(

# %%
from skimage import color
from skimage.feature import hog
from skimage import data, exposure, io
import matplotlib.pyplot as plt

# Loading an example image
image = data.astronaut()
image_gray = color.rgb2gray(image) # Converting image to grayscale

# Extract HOG features
features, hog_image = hog(image_gray, orientations=9, pixels_per_cell=(8, 8),
                          cells_per_block=(2, 2), visualize=True)
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(image_gray, cmap='gray')
plt.title('Input image')

plt.subplot(1, 2, 2)
plt.imshow(hog_image, cmap='gray')
plt.title('HOG features')
plt.show()

# %%
import numpy as np
from skimage import io
from skimage.color import rgb2gray
from skimage.feature import graycomatrix, graycoprops

# Load an image
image = io.imread('pic1.jpg')
gray_image = rgb2gray(image)

# Convert the image to 8-bit unsigned integers
gray_image = (gray_image * 255).astype(np.uint8)

# Compute GLCM
distances = [1, 2, 3]  # distances to compute the matrix for
angles = [0, np.pi/4, np.pi/2, 3*np.pi/4]  # angles in radians
glcm = graycomatrix(gray_image, distances=distances, angles=angles, symmetric=True, normed=True)

# Extract features
contrast = graycoprops(glcm, 'contrast')
dissimilarity = graycoprops(glcm, 'dissimilarity')
homogeneity = graycoprops(glcm, 'homogeneity')
energy = graycoprops(glcm, 'energy')
correlation = graycoprops(glcm, 'correlation')
ASM = graycoprops(glcm, 'ASM')

# Print the extracted features
print("Contrast:\n", contrast)
print("Dissimilarity:\n", dissimilarity)
print("Homogeneity:\n", homogeneity)
print("Energy:\n", energy)
print("Correlation:\n", correlation)
print("ASM:\n",ASM)
# Out:
# Contrast:
#
#  [[ 31.53421261  48.63630376  29.16866351  58.00852482]
#
#  [ 90.52216298  48.63630376  85.73436843  58.00852482]
#
#  [148.46611923 126.59022988 142.68047132 145.46556633]]
#
# Dissimilarity:
#
#  [[2.20743545 3.04456826 2.2670345  3.05238627]
#
#  [3.71371033 3.04456826 3.78056865 3.05238627]
#
#  [4.61481844 4.6582592  4.6857597  4.64764202]]
#
# Homogeneity:
#
#  [[0.56456596 0.4778924  0.55210359 0.48469809]
#
#  [0.45845647 0.4778924  0.4548353  0.48469809]
#
#  [0.41802238 0.39292706 0.41695245 0.4001296 ]]
#
# Energy:
#
#  [[0.12575415 0.11047036 0.1248166  0.11099494]
#
#  [0.10811845 0.11047036 0.10888591 0.11099494]
#
#  [0.09877171 0.09195665 0.09980329 0.09254182]]
#
# Correlation:
#
#  [[0.99642879 0.99449234 0.99669732 0.99343102]
#
#  [0.98974715 0.99449234 0.99029317 0.99343102]
#
#  [0.983182   0.98566371 0.98384674 0.9835261 ]]
#
# ASM:
#
#  [[0.01581411 0.0122037  0.01557918 0.01231988]
#
#  [0.0116896  0.0122037  0.01185614 0.01231988]
#
#  [0.00975585 0.00845603 0.0099607  0.00856399]]
